# %%
using CairoMakie, DSP

# %%
t=-40:0.01:40
pp(t) = (abs(t)<0.0001) ? 0.0 : (sin(t/4))^2/(t/4)
y = pp.(t)
f1 = Figure()
ax1 = Axis(f1[1, 1])
scatter!(ax1, t, abs.(y))
f1

# %%
ϕ(t) = (t< 0) ? 0 : (t> 1) ? 0 : 1
Haar(t) = ( 0 ≤ t < 0.5) ? 1 : ( 0.5 ≤ t < 1) ? -1 : 0
# Out:
# Haar (generic function with 1 method)

# %%
s = -2:0.01:2
f = Figure()
ax = Axis(f[1, 1])
lines!(ax, s, ϕ.(s), label = L"\phi(t)")
lines!(ax, s, Haar.(s), label = "Haar")
axislegend()
f

# %%
s=-5:0.01:5
phis = @. exp(-s^2)
haars = Haar.(s)
t=conv(phis, haars)
f3 = Figure()
ax3= Axis(f3[1, 1])
lines!(ax3, s, t[500:end-501])
f3

# %%
for i in 1:5:500
    println("($(t[i]), $(t[501+i]))")
end
# Out:
# (-9.022764898540954e-16, 2.9234181691045246e-11)
# (1.804552979708191e-15, 1.3366008123927122e-10)
# (-2.7068294695622863e-15, 3.0467982281744107e-10)
# (0.0, 5.833664133769204e-10)
# (-9.022764898540954e-16, 1.035235953398995e-9)
# (-1.804552979708191e-15, 1.7642579883786743e-9)
# (0.0, 2.9345575140969087e-9)
# (6.767073673905716e-16, 4.803873418986479e-9)
# (7.894919286223335e-16, 7.774839255648296e-9)
# (2.1429066634034766e-15, 1.2473161678120244e-8)
# (9.022764898540954e-16, 1.9807624464791595e-8)
# (1.804552979708191e-15, 3.1173747463490434e-8)
# (-4.511382449270477e-16, 4.886408461631603e-8)
# (9.022764898540954e-16, 7.625885836032033e-8)
# (1.804552979708191e-15, 1.1846797783330238e-7)
# (9.022764898540954e-16, 1.8317485269685603e-7)
# (0.0, 2.8187072835241866e-7)
# (9.022764898540954e-16, 4.316496136609549e-7)
# (-3.609105959416382e-15, 6.578033792590888e-7)
# (0.0, 9.975515926242454e-7)
# (-1.804552979708191e-15, 1.5053999865654438e-6)
# (0.0, 2.260697242274459e-6)
# (1.804552979708191e-15, 3.378250438698968e-6)
# (1.804552979708191e-15, 5.023426677917808e-6)
# (-1.804552979708191e-15, 7.433047320167437e-6)
# (1.804552979708191e-15, 1.0944403894672943e-5)
# (3.609105959416382e-15, 1.6035239602229372e-5)
# (3.609105959416382e-15, 2.3378499073649956e-5)
# (-3.609105959416382e-15, 3.3916832583217334e-5)
# (1.804552979708191e-15, 4.896334219698214e-5)
# (-9.022764898540954e-16, 7.033694361964427e-5)
# (-9.022764898540954e-16, 0.00010054306405286585)
# (-9.022764898540954e-16, 0.00014301328558042134)
# (1.804552979708191e-15, 0.00020242106116785498)
# (1.3534147347811431e-15, 0.0002850948637558304)
# (0.0, 0.00039955515940842234)
# (1.1278456123176193e-15, 0.0005572074915248028)
# (6.767073673905716e-16, 0.0007732307708437472)
# (1.1278456123176193e-15, 0.0010677075937322949)
# (3.383536836952858e-16, 0.0014670520170570493)
# (-3.383536836952858e-16, 0.002005799587323253)
# (7.894919286223335e-16, 0.0027288343483838624)
# (1.931435611093923e-15, 0.003694137713242275)
# (-9.022764898540954e-16, 0.004976154016901767)
# (2.4812603470987624e-15, 0.00666987663883819)
# (1.578983857244667e-15, 0.008895765977105076)
# (2.7068294695622863e-15, 0.011805615245855763)
# (1.3534147347811431e-15, 0.01558948081402183)
# (2.2556912246352386e-15, 0.020483789148561384)
# (4.511382449270477e-16, 0.02678072071924419)
# (3.157967714489334e-15, 0.03483895064997466)
# (1.3534147347811431e-15, 0.04509579455271426)
# (1.3534147347811431e-15, 0.05808076393213425)
# (1.3534147347811431e-15, 0.07443047698983951)
# (9.022764898540954e-16, 0.09490479603339334)
# (3.609105959416382e-15, 0.12040397089760035)
# (1.804552979708191e-15, 0.1519864583529792)
# (1.804552979708191e-15, 0.19088696083023876)
# (0.0, 0.23853408546789023)
# (2.7068294695622863e-15, 0.29656686938529914)
# (4.511382449270477e-15, 0.36684925364942655)
# (3.609105959416382e-15, 0.4514814228230385)
# (9.022764898540954e-16, 0.5528067672596406)
# (3.609105959416382e-15, 0.6734130812707039)
# (2.7068294695622863e-15, 0.8161264934534332)
# (1.804552979708191e-15, 0.9839965487770219)
# (9.022764898540954e-16, 1.1802708394147898)
# (1.3534147347811431e-15, 1.408357627091196)
# (3.562690292973163e-15, 1.671775027792875)
# (3.1719931122476137e-15, 1.9740855526277432)
# (1.991804002899731e-15, 2.3188151265348176)
# (2.210360426484115e-15, 2.7093561459902835)
# (1.4057582318114068e-15, 3.148854689590776)
# (2.8708726595322173e-15, 3.6400826572907223)
# (1.7969589016635293e-16, 4.185296374114579)
# (1.7002630750023303e-15, 4.7860840337306065)
# (3.710141259245958e-15, 5.443205249733756)
# (2.148834493990522e-15, 6.15642689327288)
# (1.7732475793153472e-15, 6.924360282839109)
# (1.5255554919223088e-15, 7.744305607476509)
# (1.3523298664890484e-15, 8.612110155812921)
# (1.489329239195563e-16, 9.52204743548914)
# (4.424592985902918e-17, 10.466724546935986)
# (2.0937398812105467e-16, 11.437025172254613)
# (-7.663619854396755e-17, 12.422095212083214)
# (-5.41799841229295e-16, 13.409377419919839)
# (6.907327651488515e-16, 14.384700328219107)
# (-4.673333792695169e-16, 15.332425335135143)
# (1.1558964078341792e-15, 16.235654046397347)
# (9.303272853706553e-16, 17.076495886059327)
# (8.418354256525971e-16, 17.83639366670923)
# (-1.8132319260449468e-16, 18.496502328340075)
# (1.1116504779751502e-15, 19.038113517275004)
# (-7.533435659345391e-16, 19.443116197868566)
# (-1.1440407466600884e-15, 19.69448119422718)
# (-6.324614375315424e-16, 19.77675557325258)
# (-7.533435659345391e-16, 19.676551225547623)
# (2.8050795516559993e-17, 19.383010986747532)
# (1.5023476587006994e-15, 18.888235259027653)
# (-1.08359968245859e-15, 18.187652405424572)

# %%
length(s)
# Out:
# 1001

# %%
length(t)
# Out:
# 2001
